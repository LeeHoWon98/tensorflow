# %% [markdown]
# ##구글 드라이브 연동

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Drive already mounted at drive; to attempt to forcibly remount, call drive.mount("drive", force_remount=True).

# %%
root_path = '/content/drive/MyDrive/pic2/train_set'

# %%
root_path1 = '/content/drive/MyDrive/pic2/test_set'

# %%
from keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
from tensorflow import keras
import numpy as np

# %%
train = ImageDataGenerator( rescale = 1.0/255. )
test = ImageDataGenerator( rescale = 1.0/255. )

# %%
train_data = train.flow_from_directory(root_path, batch_size=20, class_mode='binary', target_size=(150, 150))
# Out:
# Found 8005 images belonging to 2 classes.

# %%
test_data = test.flow_from_directory(root_path1, batch_size=20, class_mode='binary', target_size=(150, 150))
# Out:
# Found 2023 images belonging to 2 classes.

# %% [markdown]
# ##모델 생성

# %%
model1 = keras.Sequential()
model1.add(keras.layers.Conv2D(32,(2,2),input_shape=(150,150,3)))
model1.add(keras.layers.Flatten())
model1.add(keras.layers.Dense(1, activation = 'sigmoid'))

# %%
learning_rate = 0.001
model1.compile(optimizer = tf.keras.optimizers.Adam(learning_rate),
                  loss = 'binary_crossentropy',
                  metrics = ['accuracy'])

# %%
history = model1.fit(train_data, validation_data=test_data, steps_per_epoch=10,
                      epochs=10, validation_steps=5, verbose=2)
# Out:
# Epoch 1/10
# 10/10 - 19s - loss: 14.5276 - accuracy: 0.5000 - val_loss: 8.2265 - val_accuracy: 0.5200 - 19s/epoch - 2s/step
# Epoch 2/10
# 10/10 - 21s - loss: 4.7236 - accuracy: 0.5300 - val_loss: 2.2391 - val_accuracy: 0.6300 - 21s/epoch - 2s/step
# Epoch 3/10
# 10/10 - 21s - loss: 3.4953 - accuracy: 0.5650 - val_loss: 1.9402 - val_accuracy: 0.5400 - 21s/epoch - 2s/step
# Epoch 4/10
# 10/10 - 16s - loss: 2.6130 - accuracy: 0.4950 - val_loss: 1.9865 - val_accuracy: 0.5700 - 16s/epoch - 2s/step
# Epoch 5/10
# 10/10 - 22s - loss: 1.5674 - accuracy: 0.5200 - val_loss: 1.3626 - val_accuracy: 0.5400 - 22s/epoch - 2s/step
# Epoch 6/10
# 10/10 - 17s - loss: 1.3816 - accuracy: 0.5500 - val_loss: 1.7367 - val_accuracy: 0.4900 - 17s/epoch - 2s/step
# Epoch 7/10
# 10/10 - 18s - loss: 1.3739 - accuracy: 0.5700 - val_loss: 0.9318 - val_accuracy: 0.6600 - 18s/epoch - 2s/step
# Epoch 8/10
# 10/10 - 14s - loss: 1.2464 - accuracy: 0.5550 - val_loss: 0.8015 - val_accuracy: 0.5600 - 14s/epoch - 1s/step
# Epoch 9/10
# 10/10 - 13s - loss: 0.8141 - accuracy: 0.6150 - val_loss: 0.9154 - val_accuracy: 0.5900 - 13s/epoch - 1s/step
# Epoch 10/10
# 10/10 - 15s - loss: 0.8654 - accuracy: 0.5900 - val_loss: 1.1625 - val_accuracy: 0.4700 - 15s/epoch - 1s/step

# %% [markdown]
# ##예측률이 낮아 다시 모델 생성

# %%
model2 = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(150, 150, 3)),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(512, activation='relu'),
  tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
learning_rate = 0.001
model2.compile(optimizer = tf.keras.optimizers.Adam(learning_rate),
                  loss = 'binary_crossentropy',
                  metrics = ['accuracy'])

# %%
history = model2.fit(train_data, validation_data = test_data, steps_per_epoch=50,
                      epochs=30, validation_steps=50, verbose=2)
# Out:
# Epoch 1/30
# 50/50 - 11s - loss: 0.7626 - accuracy: 0.5090 - val_loss: 0.6878 - val_accuracy: 0.5250 - 11s/epoch - 226ms/step
# Epoch 2/30
# 50/50 - 10s - loss: 0.6904 - accuracy: 0.5670 - val_loss: 0.6773 - val_accuracy: 0.5960 - 10s/epoch - 205ms/step
# Epoch 3/30
# 50/50 - 11s - loss: 0.6799 - accuracy: 0.5760 - val_loss: 0.6750 - val_accuracy: 0.5420 - 11s/epoch - 211ms/step
# Epoch 4/30
# 50/50 - 11s - loss: 0.6558 - accuracy: 0.6170 - val_loss: 0.6416 - val_accuracy: 0.6550 - 11s/epoch - 213ms/step
# Epoch 5/30
# 50/50 - 10s - loss: 0.6321 - accuracy: 0.6528 - val_loss: 0.7639 - val_accuracy: 0.5000 - 10s/epoch - 206ms/step
# Epoch 6/30
# 50/50 - 10s - loss: 0.6798 - accuracy: 0.6000 - val_loss: 0.6356 - val_accuracy: 0.6440 - 10s/epoch - 206ms/step
# Epoch 7/30
# 50/50 - 11s - loss: 0.6157 - accuracy: 0.6570 - val_loss: 0.6114 - val_accuracy: 0.6880 - 11s/epoch - 214ms/step
# Epoch 8/30
# 50/50 - 10s - loss: 0.5934 - accuracy: 0.6850 - val_loss: 0.5977 - val_accuracy: 0.6940 - 10s/epoch - 205ms/step
# Epoch 9/30
# 50/50 - 10s - loss: 0.5533 - accuracy: 0.7250 - val_loss: 0.5866 - val_accuracy: 0.6770 - 10s/epoch - 207ms/step
# Epoch 10/30
# 50/50 - 10s - loss: 0.5972 - accuracy: 0.6810 - val_loss: 0.5734 - val_accuracy: 0.6990 - 10s/epoch - 209ms/step
# Epoch 11/30
# 50/50 - 10s - loss: 0.5268 - accuracy: 0.7340 - val_loss: 0.6175 - val_accuracy: 0.6660 - 10s/epoch - 208ms/step
# Epoch 12/30
# 50/50 - 10s - loss: 0.5751 - accuracy: 0.6954 - val_loss: 0.5626 - val_accuracy: 0.7150 - 10s/epoch - 208ms/step
# Epoch 13/30
# 50/50 - 11s - loss: 0.5184 - accuracy: 0.7574 - val_loss: 0.5625 - val_accuracy: 0.7110 - 11s/epoch - 210ms/step
# Epoch 14/30
# 50/50 - 11s - loss: 0.4827 - accuracy: 0.7540 - val_loss: 0.5582 - val_accuracy: 0.7210 - 11s/epoch - 212ms/step
# Epoch 15/30
# 50/50 - 10s - loss: 0.5007 - accuracy: 0.7500 - val_loss: 0.5567 - val_accuracy: 0.7350 - 10s/epoch - 209ms/step
# Epoch 16/30
# 50/50 - 10s - loss: 0.4831 - accuracy: 0.7550 - val_loss: 0.5761 - val_accuracy: 0.7200 - 10s/epoch - 207ms/step
# Epoch 17/30
# 50/50 - 10s - loss: 0.4641 - accuracy: 0.7820 - val_loss: 0.5104 - val_accuracy: 0.7580 - 10s/epoch - 207ms/step
# Epoch 18/30
# 50/50 - 10s - loss: 0.4631 - accuracy: 0.7790 - val_loss: 0.5019 - val_accuracy: 0.7490 - 10s/epoch - 207ms/step
# Epoch 19/30
# 50/50 - 10s - loss: 0.4203 - accuracy: 0.8240 - val_loss: 0.5410 - val_accuracy: 0.7370 - 10s/epoch - 208ms/step
# Epoch 20/30
# 50/50 - 11s - loss: 0.4123 - accuracy: 0.8122 - val_loss: 0.5516 - val_accuracy: 0.7590 - 11s/epoch - 212ms/step
# Epoch 21/30
# 50/50 - 11s - loss: 0.4104 - accuracy: 0.8150 - val_loss: 0.5796 - val_accuracy: 0.7360 - 11s/epoch - 210ms/step
# Epoch 22/30
# 50/50 - 10s - loss: 0.3588 - accuracy: 0.8380 - val_loss: 0.5554 - val_accuracy: 0.7350 - 10s/epoch - 207ms/step
# Epoch 23/30
# 50/50 - 10s - loss: 0.3872 - accuracy: 0.8250 - val_loss: 0.5569 - val_accuracy: 0.7420 - 10s/epoch - 207ms/step
# Epoch 24/30
# 50/50 - 10s - loss: 0.4090 - accuracy: 0.8100 - val_loss: 0.5646 - val_accuracy: 0.7540 - 10s/epoch - 207ms/step
# Epoch 25/30
# 50/50 - 10s - loss: 0.3747 - accuracy: 0.8325 - val_loss: 0.6522 - val_accuracy: 0.7200 - 10s/epoch - 204ms/step
# Epoch 26/30
# 50/50 - 10s - loss: 0.3358 - accuracy: 0.8620 - val_loss: 0.6425 - val_accuracy: 0.7300 - 10s/epoch - 207ms/step
# Epoch 27/30
# 50/50 - 10s - loss: 0.3598 - accuracy: 0.8340 - val_loss: 0.5097 - val_accuracy: 0.7730 - 10s/epoch - 207ms/step
# Epoch 28/30
# 50/50 - 10s - loss: 0.3375 - accuracy: 0.8480 - val_loss: 0.5742 - val_accuracy: 0.7490 - 10s/epoch - 205ms/step
# Epoch 29/30
# 50/50 - 10s - loss: 0.3557 - accuracy: 0.8540 - val_loss: 0.5470 - val_accuracy: 0.7540 - 10s/epoch - 209ms/step
# Epoch 30/30
# 50/50 - 10s - loss: 0.3172 - accuracy: 0.8640 - val_loss: 0.5591 - val_accuracy: 0.7740 - 10s/epoch - 207ms/step

# %% [markdown]
# ##개 사진을 넣었을 경우 항상 50퍼가 넘게 출력이 됩니다.
# ##따라서 50퍼가 넘었을시 개로 이하일시 고양이로 인식합니다.

# %%
test1 = ImageDataGenerator( rescale = 1.0/255. )
test_dat3 = test1.flow_from_directory('/content/test1', batch_size=20, class_mode='binary', target_size=(150, 150))
y_pre = model2.predict(test_dat3)
if (y_pre)*100 > 50:
  print('개')
else:
  print('고양이')
# Out:
# Found 1 images belonging to 2 classes.
# 고양이
